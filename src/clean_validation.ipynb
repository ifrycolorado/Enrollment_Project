# %%
import pandas as pd
import numpy as np

# %%
# load data
df = pd.read_csv("../data/pivot_CSCurriculumFull.csv")
df
# Out:
#       Semester Admitted                     Department  \
# 0             Fall 2017  Electrical Enginrg & Comp Sci
# 1             Fall 2017                     Geophysics
# 2             Fall 2017         Electrical Engineering
# 3             Fall 2017         Electrical Engineering
# 4             Fall 2017         Electrical Engineering
# ...                 ...                            ...
# 17564       Summer 2021               Computer Science
# 17565       Summer 2021      Interdisciplinary Program
# 17566       Summer 2021               Computer Science
# 17567       Summer 2022   Non-Degree Program Undergrad
# 17568   Summer Two 2018               Computer Science
#
#                                 Major    id        Taken    Class  Type  \
# 0                    Computer Science   134    Fall 2017  CSCI128  Pass
# 1             Geophysical Engineering   135    Fall 2017  CSCI128  Pass
# 2              Electrical Engineering   137    Fall 2017  CSCI128  Pass
# ...

# %%
display(df[df['Department'] == "Electrical Enginrg & Comp Sci"]['Taken'].unique())
# Out:
# array(['Fall 2017', 'Spring 2018', 'Fall 2018', 'Summer One 2018',
#        'Spring 2019', 'Summer 2019', 'Fall 2020', 'Fall 2019',
#        'Spring 2020'], dtype=object)

# %%
display(df[df['Taken_Num'] == "UNKNOWN"])
# Out:
# Empty DataFrame
# Columns: [Semester Admitted, Department, Major, id, Taken, Class, Type, Taken_Semester, Taken_Year, Admitted_Semester, Admitted_Year, Taken_Num, Admitted_Num]
# Index: []
